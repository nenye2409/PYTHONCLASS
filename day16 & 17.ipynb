# %%
## write a simple python code for a phone store management system with MYSQL as the database

# %%
#mysql.connector or pymysql

# %%
import pymysql

# %%
mydb = pymysql.connect(
    host = 'localhost',
    user = 'root',
    port = 3306,
    password = 'gozie1'
)
mycursor = mydb.cursor()
mycursor.execute('create database PHONESTORE')
mycursor.execute('show databases')
for x in mycursor:
    print(x)
# Out:
# ('information_schema',)
# ('mysql',)
# ('nenyeacademy',)
# ('performance_schema',)
# ('phonestore',)
# ('quinnyinstitutes',)
# ('sakila',)
# ('sys',)
# ('world',)

# %%
class PhoneStore:
    def __init__(self,host,user,port,password,database):
        self.conn = pymysql.connect(
            host = host,
            user = user,
            port = port,
            password = password,
            database = database
        )
        self.cursor = self.conn.cursor()
        self.create_table()
    def create_table(self):
        self.cursor.execute('''
        CREATE TABLE IF NOT EXISTS PHONETABLE(
        ID INT AUTO_INCREMENT PRIMARY KEY NOT NULL,
        BRAND VARCHAR(150) NOT NULL,
        MODEL VARCHAR(150) NOT NULL,
        PRICE FLOAT NOT NULL
        )
        ''')
        self.conn.commit()
    def add_phone(self,brand,model,price):
        self.cursor.execute('INSERT INTO PHONETABLE(BRAND,MODEL,PRICE) VALUES(%s,%s,%s)',(brand,model,price))
        self.conn.commit()
        print('PHONE ADDED SUCCESSFULLY!')
    def search_phone(self,keyword):
        self.cursor.execute('SELECT * FROM PHONETABLE WHERE BRAND LIKE %s OR MODEL LIKE %s', (f"%{keyword}%" , f"%{keyword}%"))
        result = self.cursor.fetchall() 
        if not result:
            print('NO MATCHING RECORDS.')
        else:
            print('MATCHING PHONE ARE:')
            for row in result:
                print(row)
    def close_conn(self):
        self.cursor.close()
        self.conn.close()
def main():
    host = input('Enter MYSQL host:')
    user = input('Enter MYSQL user:')
    port = int(input('Enter MYSQL port:'))
    password = input('Enter MYSQL password:')
    database = 'phonestore'
    program = PhoneStore(host, user, port, password, database)

    while True:
        print('\nPhone Store Management System')
        print('1. Add Phone\n2. search Phone\n3. Exit')
        choice = input('Enter your choice (1/2/3):')
        if choice == '1':
            BRAND = input('Enter Phone Brand:')
            MODEL = input('Enter Phone Model:')
            PRICE = float(input('Enter Phone Price:'))
            program.add_phone(BRAND,MODEL,PRICE)
        elif choice == '2':
            keyword = input('Enter brand or model to search')
            program.search_phone(keyword)
        elif choice == '3':
            break
        else:
            print('Invalid input! Please enter 1, 2 or 3')
        #program.close_conn
main()
# Out:
# Enter MYSQL host:localhost
# Enter MYSQL user:root
# Enter MYSQL port:3306
# Enter MYSQL password:gozie1
#
# Phone Store Management System
# 1. Add Phone
# 2. search Phone
# 3. Exit
# Enter your choice (1/2/3):1
# Enter Phone Brand:Iphone
# Enter Phone Model:Iphone12
# Enter Phone Price:550000
# PHONE ADDED SUCCESSFULLY!
#
# Phone Store Management System
# 1. Add Phone
# 2. search Phone
# 3. Exit
# Enter your choice (1/2/3):1
# Enter Phone Brand:Iphone
# Enter Phone Model:Iphone 13promax
# Enter Phone Price:800000
# PHONE ADDED SUCCESSFULLY!
#
# Phone Store Management System
# 1. Add Phone
# 2. search Phone
# 3. Exit
# Enter your choice (1/2/3):Tecno
# Invalid input! Please enter 1, 2 or 3
#
# Phone Store Management System
# 1. Add Phone
# 2. search Phone
# 3. Exit
# Enter your choice (1/2/3):1
# Enter Phone Brand:Tecno
# Enter Phone Model:Tecno Spark 7
# Enter Phone Price:75000
# PHONE ADDED SUCCESSFULLY!
#
# Phone Store Management System
# 1. Add Phone
# 2. search Phone
# 3. Exit
# Enter your choice (1/2/3):2
# Enter brand or model to searchIphone
# MATCHING PHONE ARE:
# (1, 'Iphone', 'Iphone11', 550000.0)
# (2, 'Iphone', 'Iphone12', 550000.0)
# (3, 'Iphone', 'Iphone 13promax', 800000.0)
#
# Phone Store Management System
# 1. Add Phone
# 2. search Phone
# 3. Exit
# Enter your choice (1/2/3):2
# Enter brand or model to searchIphone
# MATCHING PHONE ARE:
# (1, 'Iphone', 'Iphone11', 550000.0)
# (2, 'Iphone', 'Iphone12', 550000.0)
# (3, 'Iphone', 'Iphone 13promax', 800000.0)
#
# Phone Store Management System
# 1. Add Phone
# 2. search Phone
# 3. Exit
# Enter your choice (1/2/3):3
