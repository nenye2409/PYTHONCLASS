# %%
import random
def roll_dice_game():
    player_one_wins = 0
    player_two_wins = 0

    for no_of_rows in range(10):
        player_one_roll = random.randint(1,6) + random.randint(1,6) #dice has 6 sides
        player_two_roll = random.randint(1,6) + random.randint(1,6)
        
        if player_one_roll > player_two_roll:
            player_one_wins = player_one_wins + 5
            print(f'Player one dice outcome is {player_one_roll}')
            print(f'Player two dice outcome is {player_two_roll}')
            print('Player one wins')
        elif player_two_roll > player_one_roll:
            player_two_wins = player_two_wins + 5
            print(f'Player one dice outcome is {player_one_roll}')
            print(f'Player two dice outcome is {player_two_roll}')
            print('Player two wins')
        elif player_one_roll == player_two_roll:
            player_one_wins += 1
            player_two_wins += 1
            print(f'Player one dice outcome is {player_one_roll}')
            print(f'Player two dice outcome is {player_two_roll}')
            print('Draw')
                   
       
    if player_one_wins > player_two_wins:
            print(f"Player One is the overall winner with: {player_one_wins}")
    elif player_two_wins > player_one_wins:
        print(f"Player Two is the overall winner with: {player_two_wins}")
    else:
        print('It is a draw')
        
roll_dice_game()
# Out:
# Player one dice outcome is 5
# Player two dice outcome is 8
# Player two wins
# Player one dice outcome is 3
# Player two dice outcome is 7
# Player two wins
# Player one dice outcome is 7
# Player two dice outcome is 8
# Player two wins
# Player one dice outcome is 7
# Player two dice outcome is 10
# Player two wins
# Player one dice outcome is 7
# Player two dice outcome is 6
# Player one wins
# Player one dice outcome is 7
# Player two dice outcome is 6
# Player one wins
# Player one dice outcome is 10
# Player two dice outcome is 4
# Player one wins
# Player one dice outcome is 12
# Player two dice outcome is 5
# Player one wins
# Player one dice outcome is 5
# Player two dice outcome is 10
# Player two wins
# Player one dice outcome is 4
# Player two dice outcome is 8
# Player two wins
# Player Two is the overall winner with: 30

# %%
import random
def roll_dice():
    score1 = 0
    score2 = 0
    counter = 1
    while counter <= 10:
        dice1 = random.randint(1,6) + random.randint(1,6)
        dice2 = random.randint(1,6) + random.randint(1,6)
        
        if dice1 > dice2:
            print(f'Player one dice outcome is {dice1}')
            print(f'Player two dice outcome is {dice2}')
            print('PLAYER ONE WINS')
            score1 = score1 + 5
        elif dice2 > dice1:
            print(f'Player one dice outcome is {dice1}')
            print(f'Player two dice outcome is {dice2}')
            print('PLAYER TWO WINS')
            score2 = score2 + 5
        elif dice1 == dice2:
            print(f'Player one dice outcome is {dice1}')
            print(f'Player two dice outcome is {dice2}')
            print('DRAW')
            score1 = score1 + 1
            score2 = score2 + 1
        counter +=1
    if score1 > score2:
        print(f'Player one is the overall winner with {score1}')
    
    elif score2 > score1:
        print(f'Player two is the overall winner with {score2}')
    else:
        print('It is a draw')
roll_dice()
# Out:
# Player one dice outcome is 6
# Player two dice outcome is 5
# PLAYER ONE WINS
# Player one dice outcome is 5
# Player two dice outcome is 6
# PLAYER TWO WINS
# Player one dice outcome is 5
# Player two dice outcome is 7
# PLAYER TWO WINS
# Player one dice outcome is 5
# Player two dice outcome is 11
# PLAYER TWO WINS
# Player one dice outcome is 5
# Player two dice outcome is 3
# PLAYER ONE WINS
# Player one dice outcome is 10
# Player two dice outcome is 12
# PLAYER TWO WINS
# Player one dice outcome is 6
# Player two dice outcome is 9
# PLAYER TWO WINS
# Player one dice outcome is 3
# Player two dice outcome is 4
# PLAYER TWO WINS
# Player one dice outcome is 2
# Player two dice outcome is 5
# PLAYER TWO WINS
# Player one dice outcome is 7
# Player two dice outcome is 10
# PLAYER TWO WINS
# Player two is the overall winner with 40
